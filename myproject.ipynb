# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt


# Load dataset
df1 = pd.read_csv("Datasets/supermarket_sales.csv")

df = pd.read_csv("Datasets/kc_house_data.csv")
df1.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 869  852-82-2749      A     Yangon        Normal    Male
# 737  137-63-5492      C  Naypyitaw        Normal    Male
# 665  518-17-2983      A     Yangon        Normal  Female
# 525  719-89-8991      A     Yangon        Member  Female
# 736  386-27-7606      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 869       Sports and travel       64.59         4  12.9180  271.2780
# 737  Electronic accessories       58.76        10  29.3800  616.9800
# 665     Fashion accessories       48.63         4   9.7260  204.2460
# 525       Sports and travel       91.41         5  22.8525  479.9025
# 736      Home and lifestyle       81.20         7  28.4200  596.8200
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 869   1/6/2019  13:35      Ewallet  258.36                 4.761905
# ...

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
# concise sumaary statistics
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# yr_renovated   17755.0  8.363678e+01  3.999464e+02  0.000000e+00
# zipcode        21597.0  9.807795e+04  5.351307e+01  9.800100e+04
# lat            21597.0  4.756009e+01  1.385518e-01  4.715590e+01
# long           21597.0 -1.222140e+02  1.407235e-01 -1.225190e+02
# ...

# %%
# Describe categorical features
df.describe(include='object')
# Out:
#              date waterfront   view condition      grade sqft_basement
# count       21597      19221  21534     21597      21597         21597
# unique        372          2      5         5         11           304
# top     6/23/2014         NO   NONE   Average  7 Average           0.0
# freq          142      19075  19422     14020       8974         12826

# %%
# create a dataframe copy to be used in data cleaning
df1 = df.copy(deep=True)

# check for unique values
for column in df1:
    unique_values = df1[column].unique()
    print(f"Unique values in column, \n '{column}': {unique_values},\n")
# Out:
# Unique values in column,
#  'id': [7129300520 6414100192 5631500400 ... 1523300141  291310100 1523300157],
#
# Unique values in column,
#  'date': ['10/13/2014' '12/9/2014' '2/25/2015' '2/18/2015' '5/12/2014' '6/27/2014'
#  '1/15/2015' '4/15/2015' '3/12/2015' '4/3/2015' '5/27/2014' '5/28/2014'
#  '10/7/2014' '1/24/2015' '7/31/2014' '5/29/2014' '12/5/2014' '4/24/2015'
#  '5/14/2014' '8/26/2014' '7/3/2014' '5/16/2014' '11/20/2014' '11/3/2014'
#  '6/26/2014' '12/1/2014' '6/24/2014' '3/2/2015' '11/10/2014' '12/3/2014'
#  '6/13/2014' '12/30/2014' '2/13/2015' '6/20/2014' '7/15/2014' '8/11/2014'
#  '7/7/2014' '10/28/2014' '7/29/2014' '7/18/2014' '3/25/2015' '7/16/2014'
#  '4/28/2015' '3/11/2015' '9/16/2014' '2/17/2015' '12/31/2014' '2/5/2015'
#  '3/3/2015' '8/19/2014' '4/7/2015' '8/27/2014' '2/23/2015' '12/10/2014'
#  '8/28/2014' '10/21/2014' '12/7/2014' '6/3/2014' '9/9/2014' '10/9/2014'
#  '8/25/2014' '6/12/2014' '9/12/2014' '1/5/2015' '6/10/2014' '7/10/2014'
# ...

# %%
df1.columns
df1['yr_built'] = pd.to_datetime(df1['yr_built'], format='%Y')

# split into year, month and day
df1['Built_Year'] = df1['yr_built'].dt.year
df1['Built_Month'] = df1['yr_built'].dt.month
df1['Built_day'] = df1['yr_built'].dt.day

del df1['yr_built']

df1.sample(10)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 4757   7550801206    9/4/2014   624000.0         4       3.00         1540
# 12941  3331001165   9/26/2014   305000.0         3       1.00          820
# 17792  7852090820   7/29/2014   539900.0         3       2.50         2500
# 17099  3204800430    7/8/2014   415000.0         4       1.75         1920
# 11347  7702020030   2/25/2015   533000.0         4       2.50         2590
# 2417   8078350030    6/2/2014   580000.0         4       2.50         2220
# 20720  8096800270   7/16/2014   259950.0         3       2.50         1578
# 6407   2426049174  10/29/2014   481500.0         3       2.25         1840
# 21163  2224069109   4/27/2015  1050000.0         4       3.25         2930
# 7662   4232401265  10/20/2014  1110000.0         5       3.50         3090
#
#        sqft_lot  floors waterfront  view  ... sqft_basement yr_renovated  \
# ...

# %% [markdown]
# Analysis Recap
#
# To open and read the first 5 lines with the csv module, that would look like this;

# %%
import csv
import pandas as pd # pd is the standard alias

with open("Datasets/olympic_medals.csv") as f:
    reader = csv.DictReader(f)
    olympics_data = list(reader)
    
# print the 1st 5 rows of data
for index in range(5):
    print(olympics_data[index])

# Select all data for the 3rd row(record)
olympics_data[2]

# Accessing all data for the 3rd column
print([row['Location'] for row in olympics_data][:100])
# Out:
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'G', 'Name': 'Mohamed FARAH', 'Nationality': 'GBR', 'Result': '25:05.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'S', 'Name': 'Paul Kipngetich TANUI', 'Nationality': 'KEN', 'Result': '27:05.64'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'B', 'Name': 'Tamirat TOLA', 'Nationality': 'ETH', 'Result': '27:06.26'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'G', 'Name': 'Kenenisa BEKELE', 'Nationality': 'ETH', 'Result': '27:01.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'S', 'Name': 'Sileshi SIHINE', 'Nationality': 'ETH', 'Result': '27:02.77'}
# ...

# %%
df = pd.DataFrame(olympics_data)

df.sample(5)

# Extract information in the 3rd column
df['Location'].sample(5)

# Extracting information with row
df.iloc[2]

# selecting dataframe information
df.iloc[3:10]

# loc label based indexing
df.loc[3, 'Name']

# boolean indexing ising .loc
# df.loc[df['Year'] > 2020]

df.dtypes


# Importing data using pandas
# Pandas is a popular library for efficiently wrangling data. read_csv - formats can be used for any plain text delimited file. this include but not limited to pipe(|) - psv and tab separated file(tsv)


df.head(2)

# statistical methods in pandas
# You will be able to:

# Calculate summary statistics for a series and DataFrame
# Use the .apply() or .applymap() methods to apply a function to a pandas series or DataFrame

df.info() # info provides infoation about the characteristics of the dataframe - this sort info about a dataset is called metadata
df.describe() # calculates the basic summary statistics

# Calculating individual column stats

# Get the mean of every numeric column 
df.mean()

# Get the mean of a specific column
df1.sample(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   object
#  4   Medal        2394 non-null   object
#  5   Name         2394 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2394 non-null   object
# dtypes: object(8)
# memory usage: 149.8+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 41
#      36 df.describe() # calculates the basic summary statistics
#      38 # Calculating individual column stats
#      39
#      40 # Get the mean of every numeric column
# ---> 41 df.mean()
# ...

# %%
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...
